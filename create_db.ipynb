# %%
import pandas as pd

# %%
upc_data = pd.read_csv("upc_corpus.csv")
# Out:
# C:\Users\rada_\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print(upc_data)
# Out:
#                   ean                                               name
# 0        725177540363  Belle and The Yank 1/4" - 20 TPI x 90mm Hex Dr...
# 1        725177540370  Belle and The Yank 1/4" - 20 TPI x 120mm Hex D...
# 2        797776092321       Eazel Wines 750ml Red Wine Eazel Shiraz 2014
# 3        701197194311  IsyLei lilla IsyLei All-In-One, lilla - Cono L...
# 4        797776110773                    MsConscious 370g Skinny Granola
# ...               ...                                                ...
# 1048570   52569744970                         FOXMEYER CORP. ANTI GAS FV
# 1048571   52569749616                              FOXMEYER CORP. TUSSIN
# 1048572   52569751183                        FOXMEYER CORP. FV THER SMPO
# 1048573   52569755860                         FOXMEYER CORP. COLD RELIEF
# 1048574   52569758373                            FOXMEYER CORP. FV STOOL
#
# [1048575 rows x 2 columns]

# %%
part_numbers = (upc_data.iloc[:,0]).tolist()

# %%
country_codes_data = pd.read_csv("data_csv.csv")

# %%
country_codes = country_codes_data.iloc[:,1].tolist()

# %%
import random

random.shuffle(part_numbers)
random.shuffle(country_codes)

# %%
import sqlite3

# %%
conn = sqlite3.connect('A4v1M.db')
cur = conn.cursor()

# %%
cur.execute("""
            CREATE TABLE Parts (

        partNumber INTEGER, -- a UPC code 

        partPrice INTEGER, -- in the [1, 100] range

        needsPart INTEGER, -- a UPC code

        madeIn TEXT, -- a country (2 letters) code 

        PRIMARY KEY(partNumber));""")
conn.commit()

# %%
count = 0
i = 0
while count != 1000000:
    try:
        partNumber = part_numbers_x[i]
        partPrice = random.randint(1, 100)
        needsPart = part_numbers[random.randint(0, len(part_numbers) - 1)] 
        madeIn = country_codes[random.randint(0, len(country_codes) - 1)]

        cur.execute("""insert into Parts
                        values(:partNumber, :partPrice, :needsPart, :madeIn)""", 
                            {'partNumber':partNumber, 'partPrice':partPrice, 'needsPart':needsPart, 'madeIn':madeIn})
        conn.commit()
        count += 1
    except:
        print(i)
    i += 1
conn.close()
# Out:
# 12
# 14
# 928
# 1637
# 2124
# 3400
# 8263
# 8754
# 8827
# 10682
# 10691
# 10695
# 10717
# 12354
# 12969
# 12977
# 13343
# 13361
# 13366
# 13380
# 13442
# 13446
# 13509
# 13624
# 13713
# 13718
# 13723
# 14139
# 14283
# 14299
# 15657
# 18205
# 18497
# 18643
# 18659
# 18710
# 18856
# 18859
# 20287
# 20928
# 21010
# 21102
# 21109
# 21117
# 21166
# 22026
# 24083
# 24150
# 24153
# 24186
# 24189
# 24342
# 25223
# 25252
# 26097
# 26133
# 26139
# 26168
# 26171
# 28095
# 28102
# 28108
# 28117
# 28153
# 28287
# 28881
# 28928
# 29119
# 30338
# 32370
# 32449
# 32454
# 32939
# 33240
# 33652
# 33668
# 34209
# 34234
# 34256
# 34259
# 34469
# 34506
# 34511
# 34523
# 34526
# 34552
# 34563
# 34567
# 34570
# 34577
# 34580
# 34583
# 34586
# 34589
# 34592
# 34595
# 34598
# 34601
# 34613
# 34618
# 34621
# 34632
# 34637
# 34647
# 34691
# 34750
# 34755
# 35683
# 35689
# 35700
# 35708
# 35712
# 35718
# 35728
# 36293
# 38160
# 38165
# 38475
# 38477
# 38488
# 38501
# 38509
# 38549
# 38692
# 38733
# 38759
# ...

# %%
conn.close()

# %%
s = set(part_numbers)

# %%
len(s)
# Out:
# 1043986

# %%
type(s)
# Out:
# set

# %%
list(s)
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  607526060039,
#  17.0,
#  20.0,
#  '1084301802104',
#  21.0,
#  95800000534.0,
#  708948525080.0,
#  745883566105.0,
#  5.0,
#  883484000281.0,
#  872291500060.0,
#  69579309082.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  39.0,
#  95498010662.0,
#  48001712171.0,
#  733921411111.0,
#  72530001963,
#  45.0,
#  659057279022,
#  8711500202024.0,
#  42700111921.0,
#  '741952661696',
#  '706301448021',
#  883484000311.0,
#  733921411128.0,
#  92868182073.0,
#  11150557245.0,
#  81057022016.0,
#  '25323107014',
#  752359571525.0,
#  81057022023.0,
#  678112002122.0,
#  796502523979.0,
#  74.0,
#  77.0,
#  37000052814.0,
#  79.0,
#  783707799629.0,
#  5032722301009.0,
#  796502523986.0,
#  '820633990949',
#  82000740438.0,
#  5032722301016.0,
#  806864552026.0,
#  '8442073678',
#  93.0,
#  706035581025,
# ...

# %%
import numpy as np

# %%
x = np.array(part_numbers)
x = np.unique(x)
part_numbers_x = x.tolist()
print(len(part_numbers_x))
# Out:
# 1041712

# %%
s = set(part_numbers_x)
print(len(s))
# Out:
# 1041712

# %%
print(int(2.6))
# Out:
# 2
